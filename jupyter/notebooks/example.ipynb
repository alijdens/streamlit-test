# %%
import pandas as pd

# %%
data = %sql select * from measurements


df = pd.DataFrame(data)
df["value"] = pd.to_numeric(df["value"])
# Out:
#  * postgresql://postgres:***@postgres:5432/perf_metrics
# 20 rows affected.

# %%
# %matplotlib inline
df.hist(column="value", bins=10)
# Out:
# array([[<Axes: title={'center': 'value'}>]], dtype=object)
